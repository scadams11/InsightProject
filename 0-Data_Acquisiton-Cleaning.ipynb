# %%
from pybaseball import schedule_and_record ##Module available to scrape mutiple sources
##See here: https://github.com/jldbc/pybaseball

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
##Define empty dataframe to catch results from Baseball Reference
data = pd.DataFrame()

##Search for all years in Atlanta.
for year in range(1966, 2020) :
    
    ##Dump results in a temp variable.
    temp = schedule_and_record(year, 'ATL')

    ##Define the year for each game and add a column. Append to empty dataframe.
    temp['year'] = year
    data = data.append(temp, ignore_index = False) ##ignore_index = False would 
                                                  ##keep game of season correct for each year
    
##Tidy up a bit by placing year column next to date.
year = data['year']
data.drop(labels=['year'], axis = 1, inplace = True)
data.insert(1, 'year', year)

data.tail()
# Out:
#                   Date  year   Tm Home_Away  Opp   W/L     R   RA   Inn  \
# 158    Tuesday, Sep 24  2019  ATL         @  KCR     L   6.0  9.0   9.0
# 159  Wednesday, Sep 25  2019  ATL         @  KCR     W  10.0  2.0   9.0
# 160     Friday, Sep 27  2019  ATL         @  NYM     L   2.0  4.0   9.0
# 161   Saturday, Sep 28  2019  ATL         @  NYM     L   0.0  3.0   9.0
# 162     Sunday, Sep 29  2019  ATL         @  NYM  L-wo   6.0  7.0  11.0
#
#        W-L  Rank      GB      Win         Loss  Save  Time D/N  Attendance  \
# 158  96-62   1.0  up 7.5    Duffy      Teheran  None  3:28   N     16688.0
# 159  97-62   1.0  up 7.5  Jackson       Barnes  None  3:31   N     16931.0
# 160  97-63   1.0  up 6.0  Stroman      Keuchel  Lugo  3:09   N     26264.0
# 161  97-64   1.0  up 5.0     Matz  Foltynewicz  Diaz  2:33   N     32210.0
# 162  97-65   1.0  up 4.0    Mazza       Dayton  None  3:44   D     31523.0
#
#      Streak Orig. Scheduled
# 158      -2            None
# 159       1            None
# 160      -1            None
# 161      -2            None
# 162      -3            None

# %%
##We are currently only interested in home games. Removing all away ('@') rows.
home = data['Home_Away']=='Home'
data_home = data[home]
data_home.columns
# Out:
# Index(['Date', 'year', 'Tm', 'Home_Away', 'Opp', 'W/L', 'R', 'RA', 'Inn',
#        'W-L', 'Rank', 'GB', 'Win', 'Loss', 'Save', 'Time', 'D/N', 'Attendance',
#        'Streak', 'Orig. Scheduled'],
#       dtype='object')

# %%
##Extract Day of the week and Month_day from the Date column.
s = data_home['Date'].str.split(pat = ", ", expand = True)

##Add back as serpate columns
data_home.drop(labels = ['Date'], axis = 1, inplace = True)
data_home.insert(0, 'Day of Week', s[0])
data_home.insert(1, 'Month_day', s[1])

##Same thing to extract Month and day to place in their own columns. 
##Will eventually convert to Date object in the cleaned dataframe.
s2 = data_home['Month_day'].str.split(pat = ' ', expand = True, n = 1)

##Add back as serpate columns
data_home.drop(labels = ['Month_day'], axis = 1, inplace = True)
data_home.insert(1, 'Month', s2[0])
data_home.insert(2, 'Day of Month', s2[1])

##Determine running win percentage for each game. Separate W-L column.
s3 = data_home['W-L'].str.split(pat = '-', expand = True)

##Add back as separate W and L columns, plus calculate the win percentage: W/(W+L)
data_home.drop(labels = ['W-L'], axis = 1, inplace = True)
data_home.insert(11, 'Losses', s3[1])
data_home.insert(11, 'Wins', s3[0])

data_home.tail()
# Out:
#     Day of Week Month Day of Month  year   Tm Home_Away  Opp W/L    R   RA  \
# 153   Wednesday   Sep           18  2019  ATL      Home  PHI   L  1.0  4.0
# 154    Thursday   Sep           19  2019  ATL      Home  PHI   W  5.0  4.0
# 155      Friday   Sep           20  2019  ATL      Home  SFG   W  6.0  0.0
# 156    Saturday   Sep           21  2019  ATL      Home  SFG   W  8.0  1.0
# 157      Sunday   Sep           22  2019  ATL      Home  SFG   L  1.0  4.0
#
#           ...        Rank      GB          Win     Loss      Save  Time D/N  \
# 153       ...         1.0  up 9.0        Eflin  Teheran     Neris  2:59   N
# 154       ...         1.0  up 9.5       Soroka     Nola  Melancon  3:10   D
# 155       ...         1.0  up 9.5  Foltynewicz    Beede      None  2:21   N
# 156       ...         1.0  up 9.5        Fried    Cueto      None  2:35   N
# 157       ...         1.0  up 9.5         Webb  Keuchel     Smith  3:07   D
#
#     Attendance Streak Orig. Scheduled
# 153    27937.0     -3            None
# 154    33223.0      1            None
# 155    37419.0      2            None
# 156    40899.0      3            None
# 157    33674.0     -1            None
#
# [5 rows x 23 columns]

# %%
# Out:
#    Day of Week Month Day of Month  year   Tm Home_Away  Opp W/L    R   RA  \
# 0      Tuesday   Apr           12  1966  ATL      Home  PIT   L  2.0  3.0
# 1    Wednesday   Apr           13  1966  ATL      Home  PIT   L  0.0  6.0
# 8       Friday   Apr           22  1966  ATL      Home  NYM   W  8.0  4.0
# 9     Saturday   Apr           23  1966  ATL      Home  NYM   W  5.0  4.0
# 10      Sunday   Apr       24 (1)  1966  ATL      Home  NYM   W  5.0  2.0
# 11      Sunday   Apr       24 (2)  1966  ATL      Home  NYM   L  3.0  4.0
#
#          ...         Rank   GB         Win       Loss        Save  Time D/N  \
# 0        ...          8.0  1.0     Schwall  Cloninger        None  3:37   N
# 1        ...          9.0  2.0         Law    Johnson        None  2:04   N
# 8        ...          4.0  2.5   Cloninger   Hamilton      O'Dell  3:09   N
# 9        ...          4.0  2.5     Fischer      Selma       Olivo  2:44   D
# 10       ...          3.0  2.0  Blasingame     Fisher      O'Dell  2:53   D
# 11       ...          3.0  2.0      McGraw   Lemaster  Richardson  2:31   D
#
#    Attendance Streak  Orig. Scheduled
# 0     50671.0     -1             None
# 1     12721.0     -2             None
# 8     15665.0      4             None
# 9     19539.0      5             None
# 10        NaN      6             None
# 11    40477.0     -1             None
#
# [6 rows x 22 columns]

# %%
miss_att = pd.isna(data_home['Attendance'])

# %%
check_data = data_home.loc[miss_att]
#check_data['Attendance'] = data_home[miss_att]
check_data
# Out:
#      Day of Week Month Day of Month  year   Tm Home_Away  Opp   W/L     R  \
# 10        Sunday   Apr       24 (1)  1966  ATL      Home  NYM     W   5.0
# 26       Tuesday   May       10 (1)  1966  ATL      Home  CIN     L   2.0
# 37        Sunday   May       22 (1)  1966  ATL      Home  CHC     W   5.0
# 114     Saturday   Aug       13 (1)  1966  ATL      Home  PHI     L   2.0
# 133       Friday   Sep        2 (1)  1966  ATL      Home  HOU     W   6.0
# 135     Saturday   Sep        3 (1)  1966  ATL      Home  HOU     W  12.0
# 177       Sunday   Apr       30 (1)  1967  ATL      Home  PHI     L   4.0
# 432     Saturday   Aug        3 (1)  1968  ATL      Home  CIN     W   1.0
# 493       Sunday   Apr       13 (1)  1969  ATL      Home  CIN     W   1.0
# 538       Sunday   Jun        8 (1)  1969  ATL      Home  PIT     W  11.0
# 546       Monday   Jun       16 (1)  1969  ATL      Home  HOU     W   6.0
# 552       Sunday   Jun       22 (1)  1969  ATL      Home  SFG     L   1.0
# 582       Friday   Jul       18 (1)  1969  ATL      Home  SDP     W   6.0
# 601       Friday   Aug        8 (1)  1969  ATL      Home  NYM     L   1.0
# 605    Wednesday   Aug       13 (1)  1969  ATL      Home  PHI     W   4.0
# 710       Friday   Jun       19 (1)  1970  ATL      Home  HOU     W   7.0
# 724       Friday   Jul        3 (1)  1970  ATL      Home  SDP     W   8.0
# 732       Friday   Jul       10 (1)  1970  ATL      Home  CIN     W  11.0
# 740       Monday   Jul       20 (1)  1970  ATL      Home  CHC  W-wo   3.0
# 766       Friday   Aug       14 (1)  1970  ATL      Home  NYM     W  10.0
# 782      Tuesday   Sep        1 (1)  1970  ATL      Home  LAD     L   3.0
# 786     Saturday   Sep        5 (1)  1970  ATL      Home  SFG     W   5.0
# 827       Sunday   Apr       25 (1)  1971  ATL      Home  SDP     L   2.0
# 883       Monday   Jun       21 (1)  1971  ATL      Home  MON     W   6.0
# 887       Friday   Jun       25 (1)  1971  ATL      Home  CIN     W   8.0
# 907       Sunday   Jul       18 (1)  1971  ATL      Home  SFG     L   4.0
# 911    Wednesday   Jul       21 (1)  1971  ATL      Home  SDP  W-wo   8.0
# 942       Monday   Aug       23 (1)  1971  ATL      Home  PIT     L   3.0
# 1010      Sunday   May       28 (1)  1972  ATL      Home  SFG     L   2.0
# 1026      Friday   Jun       16 (1)  1972  ATL      Home  MON     L   4.0
# ...          ...   ...          ...   ...  ...       ...  ...   ...   ...
# 2925      Monday   Jun       25 (1)  1984  ATL      Home  HOU     L   5.0
# 2967      Friday   Aug       10 (1)  1984  ATL      Home  SDP     W   3.0
# 3092      Sunday   Jul        7 (1)  1985  ATL      Home  NYM     L   0.0
# 3150     Tuesday   Sep       10 (1)  1985  ATL      Home  LAD     L   1.0
# 3271    Saturday   Jul       26 (1)  1986  ATL      Home  NYM  W-wo   4.0
# 3418     Tuesday   Jul        7 (1)  1987  ATL      Home  NYM     L   2.0
# 3560      Friday   Jun       17 (1)  1988  ATL      Home  HOU     W   4.0
# 3595     Tuesday   Jul       26 (1)  1988  ATL      Home  CIN     L   2.0
# 3643    Saturday   Sep       17 (1)  1988  ATL      Home  SDP     L   4.0
# 3714      Monday   Jun        5 (1)  1989  ATL      Home  LAD     L   0.0
# 3727   Wednesday   Jun       21 (1)  1989  ATL      Home  CIN  W-wo   4.0
# 3820   Wednesday   Apr       11 (1)  1990  ATL      Home  SFG     L   0.0
# 3881     Tuesday   Jun       19 (1)  1990  ATL      Home  CIN     L   2.0
# 3901    Saturday   Jul       14 (1)  1990  ATL      Home  MON     W   3.0
# 3912     Tuesday   Jul       24 (1)  1990  ATL      Home  HOU     W   9.0
# 3925     Tuesday   Aug        7 (1)  1990  ATL      Home  SDP     L   2.0
# 4051      Friday   Jun       28 (1)  1991  ATL      Home  LAD  W-wo   3.0
# 4077      Monday   Jul       29 (1)  1991  ATL      Home  PIT     W   7.0
# 4132   Wednesday   Sep       25 (1)  1991  ATL      Home  CIN  W-wo   2.0
# 4302      Friday   Oct        2 (1)  1992  ATL      Home  SDP     W   4.0
# 4548   Wednesday   Jul        6 (1)  1994  ATL      Home  PIT     L   1.0
# 5891    Thursday   May        8 (1)  2003  ATL      Home  COL     W  12.0
# 5998      Friday   Sep        5 (1)  2003  ATL      Home  PIT  W-wo   3.0
# 6157   Wednesday   Sep        8 (1)  2004  ATL      Home  PHI     L   3.0
# 6177     Tuesday   Sep       28 (1)  2004  ATL      Home  NYM     L   1.0
# 6314   Wednesday   Aug       31 (1)  2005  ATL      Home  WSN     W   5.0
# 6488   Wednesday   Sep       13 (1)  2006  ATL      Home  PHI     L   5.0
# 7168    Saturday   Apr       16 (1)  2011  ATL      Home  NYM     W   4.0
# 7185   Wednesday   May        4 (1)  2011  ATL      Home  MIL     W   8.0
# 7963      Sunday   Oct        4 (1)  2015  ATL      Home  STL     W   6.0
#
#         RA       ...         Rank      GB          Win         Loss  \
# 10     2.0       ...          3.0     2.0   Blasingame       Fisher
# 26     8.0       ...          7.0     7.0      Maloney     Lemaster
# 37     2.0       ...          7.0     7.5   Blasingame    Ellsworth
# 114    4.0       ...          7.0    14.0      Bunning      Johnson
# 133    5.0       ...          7.0    13.5      Carroll       Taylor
# 135    2.0       ...          7.0    13.0      Vaughan       Giusti
# 177    6.0       ...          3.0     4.0      Jackson      Carroll
# 432    0.0       ...          2.0    14.0         Reed       Culver
# 493    0.0       ...          1.0  up 2.0       Niekro    Cloninger
# 538   10.0       ...          1.0  up 2.0       Niekro  Hartenstein
# 546    2.0       ...          1.0  up 2.5       Niekro      Dierker
# 552    5.0       ...          2.0     0.5     Marichal       Pappas
# 582    2.0       ...          1.0    Tied         Reed    Santorini
# 601    4.0       ...          1.0    Tied      Koosman       Pappas
# 605    2.0       ...          2.0     2.0       Pappas       Boozer
# 710    6.0       ...          2.0     9.0         Reed          Ray
# 724    1.0       ...          3.0    15.0         Nash        Kirby
# 732    9.0       ...          3.0    17.0         Reed      Merritt
# 740    1.0       ...          3.0    19.0       Niekro     Holtzman
# 766    2.0       ...          3.0    20.0         Reed         Ryan
# 782    6.0       ...          4.0    20.0         Lamb       Niekro
# 786    2.0       ...          4.0    19.0       Niekro      Johnson
# 827    3.0       ...          3.0     4.0      Roberts       Niekro
# 883    4.0       ...          5.0    15.0       Upshaw      Raymond
# 887    6.0       ...          4.0    14.5       Priddy      Merritt
# 907    5.0       ...          4.0    11.0      Johnson       Priddy
# 911    7.0       ...          3.0    10.5       Upshaw   Severinsen
# 942    4.0       ...          3.0     9.5        Blass       Niekro
# 1010   3.0       ...          4.0     8.0        Stone     Schueler
# 1026   7.0       ...          4.0     8.0       Walker      Hoerner
# ...    ...       ...          ...     ...          ...          ...
# 2925   8.0       ...          2.0     4.0       LaCoss       Barker
# 2967   1.0       ...          2.0     9.5    Bedrosian     Dravecky
# 3092   4.0       ...          5.0    12.0    Fernandez        Smith
# 3150  10.0       ...          5.0    23.5    Honeycutt        Perez
# 3271   3.0       ...          5.0     8.0  Assenmacher     McDowell
# 3418   6.0       ...          4.0     8.5        Leach       Mahler
# 3560   3.0       ...          6.0    11.0  Assenmacher     Andersen
# 3595   3.0       ...          6.0    23.5     Browning        Smith
# 3643   9.0       ...          6.0    35.0         Show        Smith
# 3714   7.0       ...          6.0     9.5     Martinez        Smith
# 3727   3.0       ...          6.0    13.0     Eichhorn       Franco
# 3820   8.0       ...          3.0     1.5     Reuschel      Glavine
# 3881   4.0       ...          6.0    17.0     Charlton      Luecken
# 3901   2.0       ...          5.0    18.0      Mercker      Schmidt
# 3912   3.0       ...          5.0    20.5    Leibrandt     Deshaies
# 3925   7.0       ...          6.0    23.0        Benes      Glavine
# 4051   2.0       ...          3.0     5.5      Mercker         Gott
# 4077   5.0       ...          2.0     4.5      Glavine       Drabek
# 4132   1.0       ...          2.0     1.5         Pena        Power
# 4302   1.0       ...          1.0  up 8.0         Nied        Benes
# 4548   3.0       ...          1.0  up 1.5        Smith      Wohlers
# 5891   6.0       ...          1.0  up 2.0     Reynolds         Cruz
# 5998   2.0       ...          1.0  up11.0      Cunnane        Corey
# 6157   5.0       ...          1.0  up 7.0       Madson      Reitsma
# 6177   2.0       ...          1.0  up11.0     Trachsel         Byrd
# 6314   3.0       ...          1.0  up 4.0      Ramirez       Loaiza
# 6488   6.0       ...          4.0    21.0        White      Paronto
# 7168   2.0       ...          3.0     3.0         Lowe     Carrasco
# 7185   3.0       ...          3.0     4.5       Hanson      Estrada
# 7963   0.0       ...          4.0    23.0       Miller       Lackey
#
#             Save  Time D/N Attendance Streak  Orig. Scheduled
# 10        O'Dell  2:53   D        NaN      6             None
# 26     Nottebart  2:25   N        NaN     -4             None
# 37         Olivo  2:50   D        NaN      1             None
# 114      Knowles  2:40   N        NaN     -1             None
# 133       Niekro  2:33   N        NaN      1             None
# 135      Ritchie  2:45   N        NaN      3             None
# 177         Hall  2:26   D        NaN     -1             None
# 432         None  1:49   N        NaN      3             None
# 493         None  2:20   D        NaN      1             None
# 538         None  2:57   D        NaN      1             None
# 546         None  1:57   N        NaN      2             None
# 552         None  2:20   D        NaN     -2             None
# 582         None  2:06   N        NaN      2             None
# 601         None  2:24   N        NaN     -1             None
# 605       Upshaw  1:59   N        NaN      1             None
# 710         None  2:50   N        NaN      1             None
# 724         None  2:17   N        NaN      1             None
# 732      Navarro  2:53   N        NaN      1             None
# 740         None  2:25   N        NaN      1             None
# 766         None  2:22   N        NaN      4             None
# 782    Mikkelsen  2:38   N        NaN     -5             None
# 786         None  2:38   N        NaN      3             None
# 827   Severinsen  1:58   D        NaN     -4             None
# 883         None  2:28   N        NaN      1             None
# 887       Upshaw  2:45   N        NaN      1             None
# 907         None  3:25   D        NaN     -1             None
# 911         None  2:55   N        NaN      2             None
# 942       Giusti  2:08   N        NaN     -2             None
# 1010        None  2:22   D        NaN     -2             None
# 1026  Strohmayer  3:01   N        NaN     -2             None
# ...          ...   ...  ..        ...    ...              ...
# 2925      DiPino  3:13   N        NaN     -5             None
# 2967       Moore  2:19   N        NaN      1             None
# 3092    McDowell  2:37   D        NaN     -4             None
# 3150        None  2:39   N        NaN     -2             None
# 3271        None  2:41   D        NaN      1             None
# 3418        None  2:52   N        NaN     -4             None
# 3560      Sutter  2:20   D        NaN      2             None
# 3595      Franco  2:32   N        NaN     -1             None
# 3643   McCullers  2:43   N        NaN     -6             None
# 3714        None  2:56   N        NaN     -1             None
# 3727        None  2:27   N        NaN      1             None
# 3820        None  2:26   N        NaN     -1             None
# 3881       Myers  2:58   N        NaN     -6             None
# 3901        None  2:38   N        NaN      1             None
# 3912        None  2:47   D        NaN      3             None
# 3925      Harris  3:01   N        NaN     -6             None
# 4051        None  3:35   N        NaN      3             None
# 4077     Freeman  2:43   N        NaN      1             None
# 4132        None  3:24   D        NaN      1             None
# 4302        None  2:15   D        NaN      2             None
# 4548        Dyer  2:20   D        NaN     -2             None
# 5891      Smoltz  3:00   D        NaN      3             None
# 5998        None  2:38   D        NaN      1             None
# 6157      Wagner  2:51   D        NaN     -1             None
# 6177      Looper  2:45   D        NaN     -1             None
# 6314  Farnsworth  2:47   D        NaN      1             None
# 6488      Gordon  2:50   D        NaN     -2             None
# 7168     Kimbrel  2:47   D        NaN      1             None
# 7185        None  3:14   D        NaN      3             None
# 7963        None  2:14   D        NaN      2             None
#
# [124 rows x 22 columns]

# %%
plt.hist(data_home['Day of Week'], 
         bins = 7,
         align = 'mid',
         rwidth = 0.75)

plt.xlabel('Day of the Week')
plt.xticks(rotation=90, 
           ticks = [0.4, 1.3, 2.1, 3.0, 3.8, 4.7, 5.6])

plt.ylabel('Games on each Day of the Week')

plt.show()
